# %%
import pandas as pd

excel_file_name = 'c:/myPyCode/data/play_typing3.xlsx'

df = pd.read_excel(excel_file_name, index_col = '학생')

df
# Out:
#      1day_tp  1day_ex 2day_tp 2day_ex  3day_tp  3day_ex  4day_tp 4day_ex  \
# 학생
# 김승규      336      100     298      99      387    100.0      317      99
# 김정훈      102       99     120      99      132    100.0      150     100
# 마가진        5       62      35      99       87     98.0       74      95
# 문지현      230      100     229      99      229     99.0      229     100
# 신준호      278      100     242     100      256     99.0      261     100
# 신지환      258      100      결석      결석      269    100.0      272     100
# 오병훈      156       99     161      99      171     99.0      169      99
# 오창환      157      100     167     100      163    100.0      173     100
# 윤경주      151       99     167     100      165      NaN  202(병결)  99(병결)
# 윤혜수      123       99     157      99      150    100.0      172      99
# 이도원      269       98     277      97      269     99.0      266     100
# 이용주      177       99     178      99      190     99.0      186     100
# ...

# %%
name = input('이름을 입력해주세요 : ')

import pandas as pd

excel_file_name = 'c:/myPyCode/data/play_typing3.xlsx'

df = pd.read_excel(excel_file_name)

# tp = df[(df['학생'] == name) & (df['1day_tp']>=100)]

tp = df[df['학생'] == name]
tp.iloc[:,[0,1,2,3,4]]
# Out:
# 이름을 입력해주세요 : 조철호
#      학생  1day_tp  1day_ex 2day_tp 2day_ex
# 15  조철호      225       99     264      99

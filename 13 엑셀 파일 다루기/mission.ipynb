# %% [markdown]
# ### mission : 공공데이터 아무거나 주피터노트북으로 가져와보기 csv or excel 파일

# %%
# csv 파일 불러오기

import pandas as pd

pd.read_csv('c:\myPyCode\data\Gwanakgu_corona.csv', encoding='cp949') # 인코딩을 해야지 한글이 안깨진다.
# Out:
#          확진일  봉천동  신림동  남현동  청림동  성현동
# 0   20200225  1.0  NaN  NaN  NaN  NaN
# 1   20200226  1.0  NaN  NaN  NaN  NaN
# 2   20200229  1.0  NaN  NaN  NaN  NaN
# 3   20200302  1.0  NaN  NaN  NaN  NaN
# 4   20200306  1.0  NaN  NaN  NaN  NaN
# ..       ...  ...  ...  ...  ...  ...
# 78  20200815  1.0  1.0  1.0  NaN  NaN
# 79  20200816  NaN  1.0  1.0  NaN  NaN
# 80  20200818  5.0  1.0  NaN  NaN  NaN
# 81  20200819  1.0  1.0  NaN  NaN  NaN
# 82  20200820  1.0  NaN  NaN  NaN  NaN
#
# [83 rows x 6 columns]

# %%
# excel 파일 불러오기

import pandas as pd

df_typing = pd.read_excel('c:/myPyCode/data/play_typing.xlsx', index_col = '학생')
df_typing.tail(6)
# Out:
#      2020-10-05 2020-10-06  2020-10-07 2020-10-12 2020-10-13  2020-10-14  \
# 학생
# 조철호         225        264         268        241        212       236.0
# 지승배         199        232         237        228        229       236.0
# 최종준          89        103         112        118        103       120.0
# 편효범         221        246         238        228        208       222.0
# 황영범         156         88         117        143        125       135.0
# 황정현         182        175         195        205        200       197.0
#
#      2020-10-15  2020-10-16 2020-10-19 2020-10-20 2020-10-21 2020-10-22  \
# 학생
# 조철호       255.0       240.0        269        274        261        260
# 지승배       243.0       225.0        224        230        239        244
# 최종준       103.0       114.0        124        144        114        111
# 편효범       237.0       220.0        231        238        237        239
# 황영범       146.0       144.0         결석        153        150        165
# ...

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'    # 맑은 고딕으로 설정
matplotlib.rcParams['axes.unicode_minus'] = False

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df_typing = pd.read_excel('c:/myPyCode/data/play_typing.xlsx', index_col = '학생')

name = input('이름을 입력하세요 :')

df_stn = df_typing.loc[name]
df_tp = df_stn.plot(grid = True, title = name + '님의 타이핑')
df_tp.set_xlabel('날짜')
df_tp.set_ylabel('타수', rotation = 360)

plt.show()
# Out:
# 이름을 입력하세요 :조철호

# %% [markdown]
# ### 마크다운 이미지 삽입

# %% [markdown]
# #### 웹이미지 불러오기

# %% [markdown]
# ![python image](https://e7.pngegg.com/pngimages/202/504/png-clipart-microsoft-excel-computer-icons-microsoft-office-microsoft-word-logo-prelude-microsoft-excel-computer-icons.png)

# %% [markdown]
# #### 로컬 이미지 불러오기

# %% [markdown]
# ![title](excel.png)

# %%
from IPython.display import Image

# %%
Image('c:\myPyCode\data\excel.png')
